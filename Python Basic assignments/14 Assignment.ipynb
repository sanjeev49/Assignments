# %% [markdown]
# ## Answer 1
# - The `rgba` stand for `red green blue alpha`.

# %% [markdown]
# ## Answer 2

# %%
from PIL import Image
x = 10
y = 20
value   = 30

im = Image.open(r'C:\Users\Sanjeev\Downloads\parrot.jpg')
pix = im.load()
print(im.size)  # Get the width and hight of the image for iterating over
print(pix[x,y])  # Get the RGBA Value of the a pixel of an image
pix[x,y] = value  # Set the RGBA Value of the image (tuple)
im.save('alive_parrot.png')  # Save the modified pixels as .png
# Out:
# (2919, 3985)
# (68, 93, 1)

# %% [markdown]
# ## Answer 3

# %%
# A tuple with no element is called empty tuples.

# %% [markdown]
# ## Answer 4

# %%
im = Image.open(r'C:\Users\Sanjeev\Downloads\parrot.jpg')

# %%
print("The width of the image is ", im.width)
print("The heigth of the image is ", im.height)
# Out:
# The width of the image is  2919
# The heigth of the image is  3985

# %% [markdown]
# ## Answer 5

# %%
width, height = im.size
im.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x246399D56A0>

# %% [markdown]
# ## Answer 6

# %%
im.save('small_parrot.jpg')

# %% [markdown]
# ## Answer 7
