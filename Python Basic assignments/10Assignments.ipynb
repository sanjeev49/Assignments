# %% [markdown]
# ## Answer 1

# %%
import os
import shutil
os.getcwd()
# Out:
# 'C:\\Users\\Sanjeev\\ineuron\\Python Basic assignments'

# %%
shutil.copy('1Assignment.ipynb', 'E:\myfiles2')
# Out:
# 'E:\\myfiles2\\1Assignment.ipynb'

# %% [markdown]
# #### Shutil copy is used to copy the file , while copytree() is used to copy the entire folder with its file tree at the destination.

# %%
# it is also used for keep a backup of the file.
shutil.copytree('D:\Downloads', 'E:\myfiless')
# Out:
# 'E:\\myfiless'

# %% [markdown]
# ## Answer 2

# %%
#What function is used to rename files?
# the os.rename function is used to rename files.
source = r'C:\Users\Sanjeev\Downloads\download.pdf'
destination = r'C:\Users\Sanjeev\Downloads\result.pdf'
os.rename(source, destination)

# %%
print("the file name of the following file is changed..>>")
# Out:
# the file name of the following file is changed..>>

# %% [markdown]
# ## Answer 3

# %% [markdown]
# * Calling shutil.rmtree(path) will remove the folder at path, and all files and folders it contains will also be deleted.
#
# * Send2trash will delete the file/folder but it is safer than shutil.rmtree() because it will save tha backup to recycle bin.

# %% [markdown]
# ## Practice

# %%
for foldername,  subfolder, filename in os.walk(r'C:\Users\Sanjeev\Downloads'):
    print("the current folder is ", foldername)
    for folder in subfolder:
        print("the subfolder is ", folder)
        for file in filename:
            print("the name of the file is ",file)
# Out:
# the current folder is  C:\Users\Sanjeev\Downloads
# the subfolder is  Codeacadmy-Projects
# the name of the file is  --+template-infinity-scroll.zip
# the name of the file is  --+template-joke-teller.zip
# the name of the file is  --+template-quote-generator.zip
# the name of the file is  1000 Seo.csv
# the name of the file is  1000 Seo.xlsx
# the name of the file is  1250 Seo (1).xlsx
# the name of the file is  1250 Seo (2).xlsx
# the name of the file is  1250 Seo.xlsx
# the name of the file is  anders-jilden-cYrMQA7a3Wc-unsplash.jpg
# the name of the file is  bokeh_plot.png
# the name of the file is  cancer_b.csv
# the name of the file is  cancer_m.csv
# the name of the file is  chocolate-en-gb-suggestions-2021-03-01t17_19_17z.csv
# the name of the file is  choosing-plot-types-and-custom-styles.ipynb
# the name of the file is  concrete.csv
# the name of the file is  Confirmation Letter (Basant Kumar).pdf
# the name of the file is  Confirmation Letter (sanjeev kumar).pdf
# ...

# %% [markdown]
# ## Answer 4

# %% [markdown]
# ## zipfile.zipfile()

# %%
import os, zipfile

# %%
os.chdir(r'C:\Users\Sanjeev\Downloads')
example = zipfile.ZipFile('--+template-infinity-scroll.zip')
example.namelist()
# Out:
# ['-- template-infinity-scroll/favicon.png',
#  '-- template-infinity-scroll/index.html',
#  '-- template-infinity-scroll/script.js',
#  '-- template-infinity-scroll/style.css',
#  '-- template-infinity-scroll/Thumbs.db']

# %% [markdown]
# ## Answer 5

# %%
def moveFileType(folder):
    for folderName, subfolders, filenames in os.walk(r'C:\Users\Sanjeev\Downloads'):
        for filename in filenames:
            if filename.endswith('.jpg'):
                shutil.copy(os.path.join(folderName, filename), 'E:\p')
print("done")
# Out:
# done
