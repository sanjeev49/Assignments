# %% [markdown]
# ### Answer 1

# %%
# built in array methods are easy to use and flexible. 
import array as built_in
array1 = built_in.array('i', [1, 2])
array1.append(3)
array1.append(4)
print(array1)
# Out:
# array('i', [1, 2, 3, 4])

# %% [markdown]
# ### Answer 2

# %% [markdown]
# Built-in array module defines an object type which can efficiently represent an array of basic values: characters, integers, floating point numbers. Arrays are sequence types and behave very much like lists, `except that the type of objects stored in them is constrained`.

# %% [markdown]
# ### Answer 3

# %% [markdown]
# Numpy arrays is a typed array, the array in memory stores a homogenous, densely packed numbers. Python list is a heterogeneous list, the list in memory stores references to objects rather than the number themselves.

# %% [markdown]
# ### Answer 4

# %%
import numpy as np

# %%
b = np.zeros(2, dtype = int)
print(b)
# Out:
# [0 0]

# %%
c = np.zeros([2,2], dtype  = int)

# %%
print(c)
# Out:
# [[0 0]
#  [0 0]]

# %%
d = np.zeros([2,2])
print(d)
# Out:
# [[0. 0.]
#  [0. 0.]]

# %%
np.empty(5)
# Out:
# array([2.12199579e-314, 2.33640564e-307, 5.57306049e-321, 1.82491638e-312,
#        2.22520458e-307])

# %%
d = np.ones(2, dtype = int)
print(d)
# Out:
# [1 1]

# %% [markdown]
# ### Answer 5

# %% [markdown]
# he function is called with N parameters, where N is the rank of shape. Each parameter represents the coordinates of the array varying along a specific axis.
#
# shape : [(N, ) tuple of ints] Shape of the output array, which also determines the shape of the coordinate arrays passed to function.

# %%
import numpy as np
cf = np.fromfunction(lambda i,j:i*j,(4,4),dtype = int)
print(cf)
# Out:
# [[0 0 0 0]
#  [0 1 2 3]
#  [0 2 4 6]
#  [0 3 6 9]]

# %%
df = np.fromfunction(lambda i,j:i==j,(3,3),dtype = int)

# %%
df
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %% [markdown]
# ### Answer 6

# %%
a = np.array([1,2,3,4,5])

# %%
print(7+a)
# Out:
# [ 8  9 10 11 12]

# %%
# the number is added to the all elements presented in the list.

# %% [markdown]
# ### Answer 7

# %%
b = np.array([3,4,5,7,8])
b +=8

# %%
print(b)
# Out:
# [11 12 13 15 16]

# %% [markdown]
# It will still add to those elements.

# %% [markdown]
# ### Answer 8

# %%
import numpy as np
  
# Create the numpy array
country = np.array(['USA', 'Japan', 'UK', '', 'India', 'China'])
  
# Print the array
print(country)
# Out:
# ['USA' 'Japan' 'UK' '' 'India' 'China']

# %%
import numpy as np

country = np.array(['USA', 'Japan', 'UK', '', 'India', 'China'], dtype = 'object')
  
# Print the array
print(country)
# Out:
# ['USA' 'Japan' 'UK' '' 'India' 'China']

# %% [markdown]
# ### Answer 9

# %%
# the combining for two numpy array is both should be same size.

# %%
c = np.array([1,2,3,4,5])
d = np.array([10,20,30,40,50])
z = c+d
y = c*d
print(z)
print()
print(y)
# Out:
# [11 22 33 44 55]
#
# [ 10  40  90 160 250]

# %% [markdown]
# ### Answer 10

# %%
A = np.array([4, 7, 3, 4, 2, 8])

print(A == 4)
# Out:
# [ True False False  True False False]

# %% [markdown]
# ## Answer 11

# %%
import numpy as np
dataset=[13, 22, 26, 38, 36, 42,49, 50, 77, 81, 98, 110]
print('Mean:', np.mean(dataset))
print('Standard Deviation:', np.std(dataset))
# Out:
# Mean: 53.5
# Standard Deviation: 29.694275542602483

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
# %matplotlib notebook

# First dataset 
City_A=[36,37,36,34,39,33,30,30,32,31,31,32,32,33,35]

# Second dataset 
City_B=[41,35,28,29,25,36,36,32,38,40,40,34,31,28,30]

# Caluclate the mean of datasets
Mean_City_A=np.mean(City_A)
Mean_City_B=np.mean(City_B)

# Caluclate the standard deviation of datasets
STDV_City_A=np.std(City_A)
STDV_City_B=np.std(City_B)

# Create a figure with customized size
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

# Set the axis lables
ax.set_xlabel('Day', fontsize = 18)
ax.set_ylabel('Temperature', fontsize = 18)

# X axis is day numbers from 1 to 15
xaxis = np.array(range(1,16))

# Line color for error bar
color_City_A = 'red'
color_City_B = 'darkgreen'

# Line style for each dataset
lineStyle_City_A={"linestyle":"--", "linewidth":2, "markeredgewidth":2, "elinewidth":2, "capsize":3}
lineStyle_City_B={"linestyle":"-", "linewidth":2, "markeredgewidth":2, "elinewidth":2, "capsize":3}

# Create an error bar for each dataset
line_City_A=ax.errorbar(xaxis, City_A, yerr=STDV_City_A, **lineStyle_City_A, color=color_City_A, label='City A')
line_City_B=ax.errorbar(xaxis, City_B, yerr=STDV_City_B, **lineStyle_City_B, color=color_City_B, label='City B')

# Label each dataset on the graph, xytext is the label's position 
for i, txt in enumerate(City_A):
        ax.annotate(txt, xy=(xaxis[i], City_A[i]), xytext=(xaxis[i]+0.03, City_A[i]+0.3),color=color_City_A)

for i, txt in enumerate(City_B):
        ax.annotate(txt, xy=(xaxis[i], City_B[i]), xytext=(xaxis[i]+0.03, City_B[i]+0.3),color=color_City_B)
        

# Draw a legend bar
plt.legend(handles=[line_City_A, line_City_B], loc='upper right')

# Customize the tickes on the graph
plt.xticks(xaxis)               
plt.yticks(np.arange(20, 47, 2))

# Customize the legend font and handle length
params = {'legend.fontsize': 13,
          'legend.handlelength': 2}
plt.rcParams.update(params)

# Customize the font
font = {'family' : 'Arial',
        'weight':'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

# Draw a grid for the graph
ax.grid(color='lightgrey', linestyle='-')
ax.set_facecolor('w')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Answer 12

# %%
import numpy as np

arr = np.asarray([[[[1, 11], [2, 22], [3, 33]],
                   [[4, 44], [5, 55], [6, 66]]],
                  [[[7, 77], [8, 88], [9, 99]],
                   [[0, 32], [1, 33], [2, 34]]]])

masked_arr = np.ma.masked_less(arr, 3)

# %%
masked_arr
# Out:
# masked_array(
#   data=[[[[--, 11],
#           [--, 22],
#           [3, 33]],
#
#          [[4, 44],
#           [5, 55],
#           [6, 66]]],
#
#
#         [[[7, 77],
#           [8, 88],
#           [9, 99]],
#
#          [[--, 32],
#           [--, 33],
#           [--, 34]]]],
#   mask=[[[[ True, False],
#           [ True, False],
#           [False, False]],
#
#          [[False, False],
#           [False, False],
#           [False, False]]],
#
#
#         [[[False, False],
#           [False, False],
#           [False, False]],
#
#          [[ True, False],
#           [ True, False],
#           [ True, False]]]],
#   fill_value=999999)
