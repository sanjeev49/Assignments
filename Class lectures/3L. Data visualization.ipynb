# %% [markdown]
# ### Pandas library

# %% [markdown]
# ### For investigation or analysis of data that is the reason why visualization is required.

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns

# %%
np.random.seed(20)
pd.DataFrame(np.random.randn(1000,1), index = pd.date_range('2021-07-18', periods = 1000), columns = ['data'])
# Out:
#                 data
# 2021-07-18  0.883893
# 2021-07-19  0.195865
# 2021-07-20  0.357537
# 2021-07-21 -2.343262
# 2021-07-22 -1.084833
# ...              ...
# 2024-04-08 -0.771658
# 2024-04-09 -0.838457
# 2024-04-10 -0.014126
# 2024-04-11  2.077352
# 2024-04-12  0.456634
#
# [1000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-7b260cc15e44> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in <module>
#     105 # cbook must import matplotlib only within function
#     106 # definitions, so it is safe to import from it here.
# --> 107 from . import cbook, rcsetup
#     108 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
#     109 from matplotlib.cbook import mplDeprecation  # deprecated
#
# ~\anaconda3\lib\site-packages\matplotlib\rcsetup.py in <module>
#      24 import numpy as np
#      25
# ---> 26 from matplotlib import animation, cbook
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.fontconfig_pattern import parse_fontconfig_pattern
#
# ...

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Sanjeev\anaconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-custom            |           py38_1          36 KB
#     ca-certificates-2021.7.5   |       haa95532_1         113 KB
#     certifi-2021.5.30          |   py38haa95532_0         140 KB
#     conda-4.10.3               |   py38haa95532_0         2.9 MB
#     matplotlib-3.3.4           |   py38haa95532_0          27 KB
#     matplotlib-base-3.3.4      |   py38h49ac443_0         5.1 MB
#     mpfr-4.0.2                 |       h62dcd97_1         1.5 MB
#     snappy-1.1.8               |       h33f27b4_0          80 KB
#     ------------------------------------------------------------
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
df['data'] = df.data.cumsum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e2edf6a8714c> in <module>
# ----> 1 df['data'] = df.data.cumsum()
#
# NameError: name 'df' is not defined

# %%
print('hi')
