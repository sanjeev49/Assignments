# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision  = 4)

# %%
pwd
# Out:
# 'C:\\Users\\Sanjeev\\ineuron\\Class lectures\\Pandas'

# %%
dr = pd.read_csv('..\..\..\Downloads\concrete.csv', index_col = ['Cement', 'FlyAsh'])

# %%
dr.head()
# Out:
#                BlastFurnaceSlag  Water  Superplasticizer  CoarseAggregate  \
# Cement FlyAsh
# 540.0  0.0                  0.0  162.0               2.5           1040.0
#        0.0                  0.0  162.0               2.5           1055.0
# 332.5  0.0                142.5  228.0               0.0            932.0
#        0.0                142.5  228.0               0.0            932.0
# 198.6  0.0                132.4  192.0               0.0            978.4
#
#                FineAggregate  Age  CompressiveStrength
# Cement FlyAsh
# 540.0  0.0             676.0   28                79.99
#        0.0             676.0   28                61.89
# 332.5  0.0             594.0  270                40.27
#        0.0             594.0  365                41.05
# 198.6  0.0             825.5  360                44.30

# %%
dk = pd.read_csv('../../../Downloads/concrete.csv')

# %%
dk.head()
# Out:
#    Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  CoarseAggregate  \
# 0   540.0               0.0     0.0  162.0               2.5           1040.0
# 1   540.0               0.0     0.0  162.0               2.5           1055.0
# 2   332.5             142.5     0.0  228.0               0.0            932.0
# 3   332.5             142.5     0.0  228.0               0.0            932.0
# 4   198.6             132.4     0.0  192.0               0.0            978.4
#
#    FineAggregate  Age  CompressiveStrength
# 0          676.0   28                79.99
# 1          676.0   28                61.89
# 2          594.0  270                40.27
# 3          594.0  365                41.05
# 4          825.5  360                44.30

# %%
dk[['Cement', 'BlastFurnaceSlag']]
# Out:
#       Cement  BlastFurnaceSlag
# 0      540.0               0.0
# 1      540.0               0.0
# 2      332.5             142.5
# 3      332.5             142.5
# 4      198.6             132.4
# 5      266.0             114.0
# 6      380.0              95.0
# 7      380.0              95.0
# 8      266.0             114.0
# 9      475.0               0.0
# 10     198.6             132.4
# 11     198.6             132.4
# 12     427.5              47.5
# 13     190.0             190.0
# 14     304.0              76.0
# 15     380.0               0.0
# 16     139.6             209.4
# 17     342.0              38.0
# 18     380.0              95.0
# 19     475.0               0.0
# 20     427.5              47.5
# 21     139.6             209.4
# 22     139.6             209.4
# 23     139.6             209.4
# 24     380.0               0.0
# 25     380.0               0.0
# 26     380.0              95.0
# 27     342.0              38.0
# 28     427.5              47.5
# ...

# %%
# if you want to pull only one row or only one column that is called series.
type(dk[['Cement', 'BlastFurnaceSlag']])
# Out:
# pandas.core.frame.DataFrame

# %%
# if i wanted to know what are all the columns available
dk.columns
# Out:
# Index(['Cement', 'BlastFurnaceSlag', 'FlyAsh', 'Water', 'Superplasticizer',
#        'CoarseAggregate', 'FineAggregate', 'Age', 'CompressiveStrength'],
#       dtype='object')

# %%
dk.columns
# Out:
# Index(['Cement', 'BlastFurnaceSlag', 'FlyAsh', 'Water', 'Superplasticizer',
#        'CoarseAggregate', 'FineAggregate', 'Age', 'CompressiveStrength'],
#       dtype='object')

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/admission.csv')
data.head()
# Out:
#    admit    gre   gpa  rank
# 0    0.0  380.0  3.61   3.0
# 1    1.0  660.0  3.67   3.0
# 2    1.0  800.0  4.00   1.0
# 3    1.0  640.0  3.19   4.0
# 4    0.0  520.0  2.93   4.0

# %%
data.head(10)
# Out:
#    admit    gre   gpa  rank
# 0    0.0  380.0  3.61   3.0
# 1    1.0  660.0  3.67   3.0
# 2    1.0  800.0  4.00   1.0
# 3    1.0  640.0  3.19   4.0
# 4    0.0  520.0  2.93   4.0
# 5    1.0  760.0  3.00   2.0
# 6    1.0  560.0  2.98   1.0
# 7    0.0  400.0  3.08   2.0
# 8    1.0  540.0  3.39   3.0
# 9    0.0  700.0  3.92   2.0

# %%
data[['admit', 'gre']]
# Out:
#      admit    gre
# 0      0.0  380.0
# 1      1.0  660.0
# 2      1.0  800.0
# 3      1.0  640.0
# 4      0.0  520.0
# 5      1.0  760.0
# 6      1.0  560.0
# 7      0.0  400.0
# 8      1.0  540.0
# 9      0.0  700.0
# 10     0.0  800.0
# 11     0.0  440.0
# 12     1.0  760.0
# 13     0.0  700.0
# 14     1.0  700.0
# 15     0.0  480.0
# 16     0.0  780.0
# 17     0.0  360.0
# 18     0.0  800.0
# 19     1.0  540.0
# 20     0.0  500.0
# 21     1.0  660.0
# 22     0.0  600.0
# 23     0.0  680.0
# 24     1.0  760.0
# 25     1.0  800.0
# 26     1.0  620.0
# 27     1.0  520.0
# 28     1.0  780.0
# 29     0.0  520.0
# ..     ...    ...
# 370    1.0  540.0
# 371    1.0  680.0
# 372    1.0  680.0
# 373    1.0  620.0
# 374    0.0  560.0
# 375    0.0  560.0
# 376    0.0  620.0
# 377    1.0  800.0
# 378    0.0  640.0
# 379    0.0  540.0
# 380    0.0  700.0
# 381    1.0  540.0
# 382    0.0  540.0
# 383    0.0  660.0
# 384    1.0  480.0
# 385    0.0  420.0
# 386    1.0  740.0
# 387    0.0  580.0
# ...

# %%
data.dtypes
# Out:
# admit    float64
# gre      float64
# gpa      float64
# rank     float64
# dtype: object

# %%
data.tail(2)
# Out:
#      admit    gre   gpa  rank
# 398    0.0  700.0  3.65   2.0
# 399    0.0  600.0  3.89   3.0

# %%
data['sanjeev'] = None

# %%
data.head(5)
# Out:
#    admit    gre   gpa  rank sanjeev
# 0    0.0  380.0  3.61   3.0    None
# 1    1.0  660.0  3.67   3.0    None
# 2    1.0  800.0  4.00   1.0    None
# 3    1.0  640.0  3.19   4.0    None
# 4    0.0  520.0  2.93   4.0    None

# %%
data
# Out:
#      admit    gre   gpa  rank sanjeev
# 0      0.0  380.0  3.61   3.0    None
# 1      1.0  660.0  3.67   3.0    None
# 2      1.0  800.0  4.00   1.0    None
# 3      1.0  640.0  3.19   4.0    None
# 4      0.0  520.0  2.93   4.0    None
# 5      1.0  760.0  3.00   2.0    None
# 6      1.0  560.0  2.98   1.0    None
# 7      0.0  400.0  3.08   2.0    None
# 8      1.0  540.0  3.39   3.0    None
# 9      0.0  700.0  3.92   2.0    None
# 10     0.0  800.0  4.00   4.0    None
# 11     0.0  440.0  3.22   1.0    None
# 12     1.0  760.0  4.00   1.0    None
# 13     0.0  700.0  3.08   2.0    None
# 14     1.0  700.0  4.00   1.0    None
# 15     0.0  480.0  3.44   3.0    None
# 16     0.0  780.0  3.87   4.0    None
# 17     0.0  360.0  2.56   3.0    None
# 18     0.0  800.0  3.75   2.0    None
# 19     1.0  540.0  3.81   1.0    None
# 20     0.0  500.0  3.17   3.0    None
# 21     1.0  660.0  3.63   2.0    None
# 22     0.0  600.0  2.82   4.0    None
# 23     0.0  680.0  3.19   4.0    None
# ...

# %%
p = data.rename(columns = {'admin':'adm'})

# %%
data[adm]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d59fb2d16eb6> in <module>
# ----> 1 data[adm]
#
# NameError: name 'adm' is not defined
